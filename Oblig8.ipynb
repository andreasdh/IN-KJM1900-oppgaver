# %% [markdown]
# # Oblig 8
#
# ## Teori
# Titrering er en kvantitativ analysemetode der vi bestemmer konsentrasjonen av et ukjent stoff (_analytten_) ved å tilsette et stoff med kjent konsentrasjon (_titranten_). Titranten tilsettes ofte fra en byrette, og vi kan notere oss pH i analytten underveis ettersom vi tilsetter et visst volum titrant.
#
# Ved ekvivalenspunktet er titreringskurven brattest, og her er stoffmengdene av syre og base _ekvivalente_ (og dermed like hvis forholdet er 1:1 i reaksjonslikningen). Dette kan vi bruke til å finne konsentrasjonen av analytten. Ved halvtitrerpunktet er $pH = pK_a$, og vi har en bufferløsning. Derfor endrer pH-en seg ikke så mye rundt dette punktet.
#
# Vi kan utlede likninger som gir oss pH-en ved tilsetting av et visst volum syre til base, eller motsatt. Når vi titrerer, tilsette vi sterke syrer til baser eller sterke baser til syrer. Derfor konsenterer vi oss om å utlede likninger som kan beskrive pH-en i slike løsninger. Vi tar utgangspunkt i en generell syre-base-titrering der vi titrerer en svak syre (HA) med en sterk base (BOH):
#
# \begin{equation}
# HA (aq) + BOH (aq) \rightleftharpoons B^+ (aq) + A^- (aq) + H_2O (l)
# \end{equation}
#
# Etter at en slik titrering er fullført, kjenner vi til følgende:
# - Konsentrasjonen av basen vi brukte (*titranten*): $c_b$.
# - Volumet base vi brukte for å nå ekvivalenspunktet: $V_b$.
# - Volumet syre vi titrerte (*analytten*): $V_a$.
# - Den tidligere ukjente konsentrasjonen av syra: $c_a$.
#
# Siden vi kjenner disse verdiene, er de å regne som konstanter når vi skal finne pH i løsningen ved ekvivalenspunktet. Vi trenger å formulere en likning som inneholder $[H^+]$, og ingen andre ukjente. La oss prøve å utlede en slik likning. Et godt utgangspunkt kan være at summen av negative ioner til enhver tid skal være lik summen av positive ioner siden løsningen alltid er elektrisk nøytral:
#
# \begin{equation}
#     [H^+] + [B^+] = [OH^-] + [A^-]
# \end{equation}
#
# Denne sammenhengen kan vi ta utgangspunkt i, men vi trenger altså å eliminere alle de ukjente konsentrasjonene bortsett fra $[H^+]$, som vi jo skal finne. Merk at $[B^+]$ og $[A^-]$ er konsentrasjonen i løsningen etter tilsatt titrant, mens $c_b$ og $c_a$ er konsentrasjon av base i titranten og syre i analytten _før_ titreringen starter (initialbetingelser).
#
# Konsentrasjonen av den korresponderende syra, $[B^+]$, til den sterke basen i _løsningen_ ved enhver tid er gitt ved antall mol base tilsatt fordelt på totalvolumet av løsningen. Dette er fordi vi regner med at all basen vi tilsetter, har reagert. Antall mol base tilsatt er det samme som konsentrasjonen av basen ved start ($c_b$) multiplisert med volumet av base som er tilsatt. Deretter får vi konsentrasjonen av base i løsningen ved å dele på totalvolumet av løsningen, $V_t = V_a + V_b$. Da får vi at:
#
# \begin{equation}
#     [B^+] = \frac{c_bV_b}{V_t}
# \end{equation}
#
# Da har vi altså fått et uttrykk for den korresponderende syra til den sterke basen. Vi mangler da blant annet et uttrykk for $[OH^-]$. Dette kan vi få fra uttrykket for _vannets egenprotolyse_:
#
# \begin{equation}
#     K_w = [OH^-][H^+]
# \end{equation}
#
# der $k_w = 10^{-14}$. Da har vi:
#
# \begin{equation}
#     [OH^-] = \frac{K_w}{[H^+]}
# \end{equation}
#
#
# Vi mangler nå et uttrykk for $[A^-]$. Vi kan utlede dette fra følgende sammenheng:
#
# \begin{equation}
#     n_{A^-} = n_{syre,start} - n_{HA}
# \end{equation}
#
# Denne sammenhengen sier at antall mol korresponderende base til en svak syre er lik antall mol syre vi startet med minus antall mol syre vi har igjen. Dette gir følgende sammenheng:
#
# \begin{equation}
#     [A^-]\cdot V_t = c_aV_a - [HA]\cdot V_t
# \end{equation}
#
# Et problem er at vi nå har en ukjent til, nemlig $[HA]$. Denne kan vi derimot eliminere ved å benytte oss av uttrykket for likevektskonstanten for en svak syre:
#
# \begin{equation}
#     K_a = \frac{[H^+][A^-]}{[HA]}
# \end{equation}
#
# Dette gir følgende uttrykk for konsentrasjonen av syra, $[HA]$:
#
# \begin{equation}
#     [HA]= \frac{[H^+][A^-]}{K_a}
# \end{equation}
#
# Hvis vi substituerer $[HA]$ fra inn i uttrykket for $[A^-]$, får vi:
#
# \begin{equation}
#     [A^-] = \frac{c_aV_a}{V_t[H^+]/K_a + V_t} = \frac{c_aV_aK_a}{V_t([H^+]+K_a)}
# \end{equation}
#
# Nå har vi uttrykk for $[A^-]$, $[OH^-]$ og $[B^+]$ som kun avhenger av én ukjent, nemlig $[H^+]$. Da kan vi sette alt inn i likningen som representere elektronøytralitet:
#
# \begin{equation}
#     [H^+] + \frac{c_bV_b}{V_t} = \frac{K_w}{[H^+]} + \frac{c_aV_aK_a}{V_t([H^+]+K_a)}
# \end{equation}
#
# Vi samler alle ledd på samme side og ganger alle ledd med $V_t$ for å fjerne flest mulige brøker:
#
# \begin{equation}
#     [H^+]V_t + c_bV_b - \frac{K_wV_t}{[H^+]} - \frac{c_aV_aK_a}{[H^+]+K_a} = 0
# \end{equation}
#
# Nå har vi en likning som vi kan løse ved å finne nullpunktene til følgende funksjon:
# \begin{equation}
#     T([H^+]) = [H^+]V_t + c_bV_b - \frac{K_wV_t}{[H^+]} - \frac{c_aV_aK_a}{[H^+]+K_a}
# \end{equation}
#
# Denne funksjonen er det derimot problematisk å finne nullpunktene til. Vi får nemlig asymptoter rundt nullpunktet fordi den ikke er definert når $[H^+] = 0$. Dette kan vi komme unna ved å gange med fellesnevner, $[H^+]\cdot(K_a + [H^+])$, i alle ledd. Da får vi følgende funksjon:
#
# \begin{equation}
#     T([H^+]) = V_t([H^+] + K_a)[H^+]^2 + c_bV_b([H^+] + K_a)[H^+] - K_wV_t([H^+] + K_a) - c_aV_aK_a[H^+]
# \end{equation}
#
# Vi ser at dette er en tredjegradsfunksjon som ikke lett lar seg løses analytisk. Vi kan derfor bruke numeriske løsninger, for eksempel Newtons metode, for å løse denne.
#
#
# ## Oppgaver
# ## 8.1
# ### a)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Datafiler/titreringsdata.txt')

plt.scatter(data["volum"], data["pH"], color = 'mediumseagreen')
plt.title('Titrerkurve for titrering av mandelsyre med NaOH')
plt.ylabel('pH')
plt.xlabel('Volum NaOH tilsatt (mL)')
plt.show()

# %% [markdown]
# b)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.losses import MeanSquaredError
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# Koden nedenfor oppretter et sekvensielt nettverk av noder (et kunstig nevralt nettverk). Vi har 5 lag med følgende oppbygning: 1 input-node, 12 gjemte noder, 8 gjemte noder, 3 gjemte noder og 1 output-node. Deretter spesifiserer vi for fort modellen skal lære (læringsraten). Så kompilerer vi modellen med en optimeringsfunksjon som heter Adam. Vi beregner avviket fra reelle data med lossfunksjonen _mean square error_ (mse).
#
# Deretter må vi tilpasse modellen vår til dataene og trene modellen.

# %%
modell1 = tf.keras.Sequential()
modell1.add(Dense(12 , activation="sigmoid", input_shape=(1,)))
modell1.add(Dense(8, activation="linear"))
modell1.add(Dense(3, activation="linear"))
modell1.add(Dense(1, activation="linear"))

læringsrate = 0.1  # Hvor fort modellen skal lære
modell1.compile(optimizer=Adam(læringsrate), loss = "mse") # Optimizer = metode for å minimere loss

# %%
x = data['volum']
y = data['pH']
modell1.fit(x, y, epochs = 2000)
# Out:
# Epoch 1/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 65.5231
# Epoch 2/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 17.1629
# Epoch 3/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 15.4819
# Epoch 4/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 21.1199
# Epoch 5/2000
# 2/2 [==============================] - 0s 999us/step - loss: 16.1399
# Epoch 6/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 11.0360
# Epoch 7/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 10.4035
# Epoch 8/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 13.7257
# Epoch 9/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 10.4389
# Epoch 10/2000
# 2/2 [==============================] - 0s 999us/step - loss: 10.3414
# Epoch 11/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 10.4410
# Epoch 12/2000
# 2/2 [==============================] - 0s 999us/step - loss: 10.3170
# Epoch 13/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 10.2864
# Epoch 14/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 10.4171
# Epoch 15/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 9.2565
# Epoch 16/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 11.1503
# Epoch 17/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 8.3833
# Epoch 18/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 8.2289
# Epoch 19/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 8.0279
# Epoch 20/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 7.3822
# Epoch 21/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 7.6984
# Epoch 22/2000
# 2/2 [==============================] - 0s 999us/step - loss: 7.5730
# Epoch 23/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 6.3065
# Epoch 24/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 5.9066
# Epoch 25/2000
# 2/2 [==============================] - 0s 998us/step - loss: 5.6995
# Epoch 26/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 6.3332
# Epoch 27/2000
# 2/2 [==============================] - 0s 999us/step - loss: 8.8482
# Epoch 28/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 5.5214
# Epoch 29/2000
# 2/2 [==============================] - 0s 998us/step - loss: 5.3304
# Epoch 30/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 7.0731
# Epoch 31/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 4.4001
# Epoch 32/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 7.8669
# Epoch 33/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 4.8220
# Epoch 34/2000
# 2/2 [==============================] - 0s 998us/step - loss: 5.1908
# Epoch 35/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 5.7939
# Epoch 36/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 8.3389
# Epoch 37/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 5.4145
# Epoch 38/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 5.9818
# Epoch 39/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 4.7619
# Epoch 40/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 4.0408
# Epoch 41/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.9887
# Epoch 42/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 4.1690
# Epoch 43/2000
# 2/2 [==============================] - 0s 999us/step - loss: 3.4500
# Epoch 44/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 3.6606
# Epoch 45/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 4.9495
# Epoch 46/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 6.1197
# Epoch 47/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 9.2207
# Epoch 48/2000
# 2/2 [==============================] - 0s 999us/step - loss: 8.9185
# Epoch 49/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 6.4044
# Epoch 50/2000
# 2/2 [==============================] - 0s 998us/step - loss: 7.4917
# Epoch 51/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 5.0592
# Epoch 52/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 5.9358
# Epoch 53/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 4.4016
# Epoch 54/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 6.8888
# Epoch 55/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 4.6387
# Epoch 56/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 6.2560
# Epoch 57/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 3.9935
# Epoch 58/2000
# 2/2 [==============================] - 0s 998us/step - loss: 6.6146
# Epoch 59/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 3.9000
# Epoch 60/2000
# 2/2 [==============================] - 0s 998us/step - loss: 4.6851
# Epoch 61/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 3.2737
# Epoch 62/2000
# 2/2 [==============================] - 0s 998us/step - loss: 3.1087
# Epoch 63/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.9560
# Epoch 64/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.8764
# Epoch 65/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.9150
# Epoch 66/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.7477
# Epoch 67/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.7660
# Epoch 68/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.7349
# Epoch 69/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.5670
# Epoch 70/2000
# 2/2 [==============================] - 0s 997us/step - loss: 2.3609
# Epoch 71/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 5.1748
# Epoch 72/2000
# 2/2 [==============================] - 0s 996us/step - loss: 3.3610
# Epoch 73/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.6808
# Epoch 74/2000
# 2/2 [==============================] - 0s 997us/step - loss: 3.0551
# Epoch 75/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 3.0205
# Epoch 76/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.4789
# Epoch 77/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 3.1049
# Epoch 78/2000
# 2/2 [==============================] - 0s 997us/step - loss: 3.2317
# Epoch 79/2000
# 2/2 [==============================] - 0s 997us/step - loss: 2.6077
# Epoch 80/2000
# 2/2 [==============================] - 0s 999us/step - loss: 3.3731
# Epoch 81/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.4136
# Epoch 82/2000
# 2/2 [==============================] - 0s 997us/step - loss: 2.5477
# Epoch 83/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.5873
# Epoch 84/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.5875
# Epoch 85/2000
# 2/2 [==============================] - 0s 997us/step - loss: 2.6388
# Epoch 86/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 4.7660
# Epoch 87/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.8941
# Epoch 88/2000
# 2/2 [==============================] - 0s 996us/step - loss: 4.0784
# Epoch 89/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 4.0460
# Epoch 90/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.8639
# Epoch 91/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 3.0510
# Epoch 92/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 3.3512
# Epoch 93/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.6447
# Epoch 94/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 3.5235
# Epoch 95/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.3884
# Epoch 96/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.4024
# Epoch 97/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.7649
# Epoch 98/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.3683
# Epoch 99/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.2277
# Epoch 100/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.9673
# Epoch 101/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 4.4599
# Epoch 102/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.3726
# Epoch 103/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.4553
# Epoch 104/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1931
# Epoch 105/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.9047
# Epoch 106/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.4186
# Epoch 107/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.6180
# Epoch 108/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.2500
# Epoch 109/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.9447
# Epoch 110/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.5157
# Epoch 111/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.7371
# Epoch 112/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.2968
# Epoch 113/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.6845
# Epoch 114/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.5038
# Epoch 115/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.3161
# Epoch 116/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.5646
# Epoch 117/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.4186
# Epoch 118/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0296
# Epoch 119/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 4.8745
# Epoch 120/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.3278
# Epoch 121/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.6992
# Epoch 122/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.6517
# Epoch 123/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.5529
# Epoch 124/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.4925
# Epoch 125/2000
# 2/2 [==============================] - 0s 996us/step - loss: 2.8360
# Epoch 126/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.8814
# Epoch 127/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.8680
# Epoch 128/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 4.6193
# Epoch 129/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.3761
# Epoch 130/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.4082
# Epoch 131/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.1622
# Epoch 132/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.3760
# Epoch 133/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.2649
# Epoch 134/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0701
# Epoch 135/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.2797
# Epoch 136/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.1645
# Epoch 137/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.3173
# Epoch 138/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.5756
# Epoch 139/2000
# 2/2 [==============================] - 0s 997us/step - loss: 2.4852
# Epoch 140/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1870
# Epoch 141/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.7549
# Epoch 142/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1237
# Epoch 143/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0690
# Epoch 144/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0739
# Epoch 145/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.3772
# Epoch 146/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0607
# Epoch 147/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.2006
# Epoch 148/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.2101
# Epoch 149/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9810
# Epoch 150/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 4.5454
# Epoch 151/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.2336
# Epoch 152/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.7904
# Epoch 153/2000
# 2/2 [==============================] - 0s 997us/step - loss: 4.1699
# Epoch 154/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.3931
# Epoch 155/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 3.5625
# Epoch 156/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1686
# Epoch 157/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.1782
# Epoch 158/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.1556
# Epoch 159/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.2508
# Epoch 160/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.4826
# Epoch 161/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.5621
# Epoch 162/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.2855
# Epoch 163/2000
# 2/2 [==============================] - 0s 999us/step - loss: 3.3475
# Epoch 164/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.1753
# Epoch 165/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1254
# Epoch 166/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.1738
# Epoch 167/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.2616
# Epoch 168/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.3042
# Epoch 169/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0390
# Epoch 170/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.5541
# Epoch 171/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.3833
# Epoch 172/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1318
# Epoch 173/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.6639
# Epoch 174/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9817
# Epoch 175/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.0499
# Epoch 176/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9345
# Epoch 177/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.1230
# Epoch 178/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.9993
# Epoch 179/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.1202
# Epoch 180/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.3808
# Epoch 181/2000
# 2/2 [==============================] - 0s 997us/step - loss: 2.7855
# Epoch 182/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.2723
# Epoch 183/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.7777
# Epoch 184/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 3.2281
# Epoch 185/2000
# 2/2 [==============================] - 0s 999us/step - loss: 3.4335
# Epoch 186/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 4.4455
# Epoch 187/2000
# 2/2 [==============================] - 0s 999us/step - loss: 3.7164
# Epoch 188/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.6062
# Epoch 189/2000
# 2/2 [==============================] - 0s 997us/step - loss: 3.3794
# Epoch 190/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.3838
# Epoch 191/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.3139
# Epoch 192/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.2939
# Epoch 193/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.1152
# Epoch 194/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7771
# Epoch 195/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.0451
# Epoch 196/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9658
# Epoch 197/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.8990
# Epoch 198/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.3120
# Epoch 199/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0630
# Epoch 200/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8905
# Epoch 201/2000
# 2/2 [==============================] - 0s 995us/step - loss: 3.1249
# Epoch 202/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0181
# Epoch 203/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 3.1577
# Epoch 204/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.1718
# Epoch 205/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.2624
# Epoch 206/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0845
# Epoch 207/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.3560
# Epoch 208/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.7661
# Epoch 209/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.3464
# Epoch 210/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.4854
# Epoch 211/2000
# 2/2 [==============================] - 0s 998us/step - loss: 3.3392
# Epoch 212/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.0638
# Epoch 213/2000
# 2/2 [==============================] - 0s 998us/step - loss: 3.3044
# Epoch 214/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.1463
# Epoch 215/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.8869
# Epoch 216/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.4931
# Epoch 217/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.9252
# Epoch 218/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9619
# Epoch 219/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0535
# Epoch 220/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.9775
# Epoch 221/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0822
# Epoch 222/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9381
# Epoch 223/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.2852
# Epoch 224/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1276
# Epoch 225/2000
# 2/2 [==============================] - 0s 996us/step - loss: 2.3788
# Epoch 226/2000
# 2/2 [==============================] - 0s 0s/step - loss: 3.0828
# Epoch 227/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.9828
# Epoch 228/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.9719
# Epoch 229/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9240
# Epoch 230/2000
# 2/2 [==============================] - 0s 997us/step - loss: 3.4678
# Epoch 231/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.3773
# Epoch 232/2000
# 2/2 [==============================] - 0s 998us/step - loss: 4.9197
# Epoch 233/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.4095
# Epoch 234/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.0319
# Epoch 235/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 3.1624
# Epoch 236/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.6702
# Epoch 237/2000
# 2/2 [==============================] - 0s 996us/step - loss: 2.7814
# Epoch 238/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.5022
# Epoch 239/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9481
# Epoch 240/2000
# 2/2 [==============================] - 0s 997us/step - loss: 2.8844
# Epoch 241/2000
# 2/2 [==============================] - 0s 997us/step - loss: 1.9680
# Epoch 242/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.4221
# Epoch 243/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8656
# Epoch 244/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7869
# Epoch 245/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.1007
# Epoch 246/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7823
# Epoch 247/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8819
# Epoch 248/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1187
# Epoch 249/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.0198
# Epoch 250/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.0864
# Epoch 251/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9738
# Epoch 252/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.2233
# Epoch 253/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.9736
# Epoch 254/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.7771
# Epoch 255/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8101
# Epoch 256/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.8001
# Epoch 257/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.8753
# Epoch 258/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.6845
# Epoch 259/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.0775
# Epoch 260/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.4366
# Epoch 261/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9619
# Epoch 262/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.4268
# Epoch 263/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.0701
# Epoch 264/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.3068
# Epoch 265/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.3308
# Epoch 266/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0399
# Epoch 267/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.5150
# Epoch 268/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.3597
# Epoch 269/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.0863
# Epoch 270/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.3892
# Epoch 271/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.3039
# Epoch 272/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.8413
# Epoch 273/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7362
# Epoch 274/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.9382
# Epoch 275/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9705
# Epoch 276/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9347
# Epoch 277/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.4119
# Epoch 278/2000
# 2/2 [==============================] - 0s 997us/step - loss: 2.1244
# Epoch 279/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.6351
# Epoch 280/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8679
# Epoch 281/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8165
# Epoch 282/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.7379
# Epoch 283/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.1236
# Epoch 284/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9811
# Epoch 285/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9051
# Epoch 286/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.8455
# Epoch 287/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.6051
# Epoch 288/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9831
# Epoch 289/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7419
# Epoch 290/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.6928
# Epoch 291/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.3278
# Epoch 292/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.8795
# Epoch 293/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7825
# Epoch 294/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.0725
# Epoch 295/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0911
# Epoch 296/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9005
# Epoch 297/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.2179
# Epoch 298/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.1936
# Epoch 299/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.7853
# Epoch 300/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.0152
# Epoch 301/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0662
# Epoch 302/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.8420
# Epoch 303/2000
# 2/2 [==============================] - 0s 996us/step - loss: 1.9195
# Epoch 304/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.7807
# Epoch 305/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8229
# Epoch 306/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8926
# Epoch 307/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9470
# Epoch 308/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.5244
# Epoch 309/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.5343
# Epoch 310/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.7065
# Epoch 311/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.9734
# Epoch 312/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.7192
# Epoch 313/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7160
# Epoch 314/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7347
# Epoch 315/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.6594
# Epoch 316/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7125
# Epoch 317/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.9734
# Epoch 318/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1659
# Epoch 319/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.9474
# Epoch 320/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.3577
# Epoch 321/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9299
# Epoch 322/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.6748
# Epoch 323/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.2310
# Epoch 324/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.0126
# Epoch 325/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.2815
# Epoch 326/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9080
# Epoch 327/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.6805
# Epoch 328/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.6277
# Epoch 329/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.6870
# Epoch 330/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.7826
# Epoch 331/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8085
# Epoch 332/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9678
# Epoch 333/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7384
# Epoch 334/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.2727
# Epoch 335/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7121
# Epoch 336/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 3.7468
# Epoch 337/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0969
# Epoch 338/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.6967
# Epoch 339/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.8841
# Epoch 340/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.2907
# Epoch 341/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.8415
# Epoch 342/2000
# 2/2 [==============================] - 0s 999us/step - loss: 3.0506
# Epoch 343/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.9984
# Epoch 344/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0569
# Epoch 345/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0981
# Epoch 346/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.9250
# Epoch 347/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8446
# Epoch 348/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.8001
# Epoch 349/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.6086
# Epoch 350/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.7590
# Epoch 351/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7652
# Epoch 352/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.1991
# Epoch 353/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0808
# Epoch 354/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.2826
# Epoch 355/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8587
# Epoch 356/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.7692
# Epoch 357/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7787
# Epoch 358/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7584
# Epoch 359/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.3088
# Epoch 360/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.7225
# Epoch 361/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.5735
# Epoch 362/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.3207
# Epoch 363/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.6691
# Epoch 364/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.7105
# Epoch 365/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1611
# Epoch 366/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.6171
# Epoch 367/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9108
# Epoch 368/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7125
# Epoch 369/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8162
# Epoch 370/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.4761
# Epoch 371/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.4728
# Epoch 372/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1661
# Epoch 373/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.3162
# Epoch 374/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9232
# Epoch 375/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.6934
# Epoch 376/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.5312
# Epoch 377/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.4115
# Epoch 378/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.6147
# Epoch 379/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.8420
# Epoch 380/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.5015
# Epoch 381/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.4730
# Epoch 382/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.1115
# Epoch 383/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.8736
# Epoch 384/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.8499
# Epoch 385/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.3712
# Epoch 386/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8626
# Epoch 387/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0705
# Epoch 388/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.7170
# Epoch 389/2000
# 2/2 [==============================] - 0s 995us/step - loss: 1.5253
# Epoch 390/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.8599
# Epoch 391/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5858
# Epoch 392/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.6985
# Epoch 393/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5815
# Epoch 394/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8975
# Epoch 395/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.7226
# Epoch 396/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.8359
# Epoch 397/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4581
# Epoch 398/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.4943
# Epoch 399/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9364
# Epoch 400/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.6554
# Epoch 401/2000
# 2/2 [==============================] - 0s 996us/step - loss: 1.6308
# Epoch 402/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9793
# Epoch 403/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4898
# Epoch 404/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7776
# Epoch 405/2000
# 2/2 [==============================] - 0s 997us/step - loss: 1.5363
# Epoch 406/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9203
# Epoch 407/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0760
# Epoch 408/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.9444
# Epoch 409/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.1777
# Epoch 410/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8414
# Epoch 411/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.6877
# Epoch 412/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.9172
# Epoch 413/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.5677
# Epoch 414/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.6636
# Epoch 415/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.0385
# Epoch 416/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.1775
# Epoch 417/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.5739
# Epoch 418/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 3.4401
# Epoch 419/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.6690
# Epoch 420/2000
# 2/2 [==============================] - 0s 999us/step - loss: 5.5614
# Epoch 421/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.7977
# Epoch 422/2000
# 2/2 [==============================] - 0s 999us/step - loss: 5.4508
# Epoch 423/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.7547
# Epoch 424/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 4.1450
# Epoch 425/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.1617
# Epoch 426/2000
# 2/2 [==============================] - 0s 999us/step - loss: 4.0791
# Epoch 427/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7496
# Epoch 428/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 4.3598
# Epoch 429/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.3200
# Epoch 430/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1498
# Epoch 431/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 3.1432
# Epoch 432/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.2434
# Epoch 433/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.0482
# Epoch 434/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.2253
# Epoch 435/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.3976
# Epoch 436/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.8783
# Epoch 437/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.5242
# Epoch 438/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 3.6003
# Epoch 439/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7506
# Epoch 440/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.6501
# Epoch 441/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8474
# Epoch 442/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.2805
# Epoch 443/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.1483
# Epoch 444/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1803
# Epoch 445/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0754
# Epoch 446/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7253
# Epoch 447/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5929
# Epoch 448/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5844
# Epoch 449/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5893
# Epoch 450/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4569
# Epoch 451/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.6685
# Epoch 452/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5404
# Epoch 453/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5384
# Epoch 454/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.7125
# Epoch 455/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4555
# Epoch 456/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.5004
# Epoch 457/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.5664
# Epoch 458/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7484
# Epoch 459/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0106
# Epoch 460/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0101
# Epoch 461/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.1556
# Epoch 462/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5427
# Epoch 463/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.7869
# Epoch 464/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.8716
# Epoch 465/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.1870
# Epoch 466/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.7952
# Epoch 467/2000
# 2/2 [==============================] - 0s 996us/step - loss: 1.8848
# Epoch 468/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.2110
# Epoch 469/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7262
# Epoch 470/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.3185
# Epoch 471/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9359
# Epoch 472/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7021
# Epoch 473/2000
# 2/2 [==============================] - 0s 999us/step - loss: 3.0140
# Epoch 474/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.0129
# Epoch 475/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.3287
# Epoch 476/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.7816
# Epoch 477/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.0787
# Epoch 478/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0814
# Epoch 479/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.9461
# Epoch 480/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0852
# Epoch 481/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.2616
# Epoch 482/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.2084
# Epoch 483/2000
# 2/2 [==============================] - 0s 0s/step - loss: 2.0829
# Epoch 484/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4150
# Epoch 485/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 4.7413
# Epoch 486/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9164
# Epoch 487/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 3.4882
# Epoch 488/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7083
# Epoch 489/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7437
# Epoch 490/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.8653
# Epoch 491/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.1032
# Epoch 492/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.6998
# Epoch 493/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9121
# Epoch 494/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.2858
# Epoch 495/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.7245
# Epoch 496/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0320
# Epoch 497/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.6647
# Epoch 498/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.8129
# Epoch 499/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.4177
# Epoch 500/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.6468
# Epoch 501/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.0319
# Epoch 502/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.6313
# Epoch 503/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.8503
# Epoch 504/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.5150
# Epoch 505/2000
# 2/2 [==============================] - 0s 999us/step - loss: 3.0385
# Epoch 506/2000
# 2/2 [==============================] - 0s 997us/step - loss: 2.7965
# Epoch 507/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.8463
# Epoch 508/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1165
# Epoch 509/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.5825
# Epoch 510/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9491
# Epoch 511/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4527
# Epoch 512/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1769
# Epoch 513/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.9969
# Epoch 514/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7657
# Epoch 515/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.8779
# Epoch 516/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.0834
# Epoch 517/2000
# 2/2 [==============================] - 0s 999us/step - loss: 2.7531
# Epoch 518/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.0511
# Epoch 519/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.1797
# Epoch 520/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.8548
# Epoch 521/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.2059
# Epoch 522/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5885
# Epoch 523/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7478
# Epoch 524/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.4276
# Epoch 525/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.6195
# Epoch 526/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4437
# Epoch 527/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.6888
# Epoch 528/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.6400
# Epoch 529/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.4338
# Epoch 530/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 2.7716
# Epoch 531/2000
# 2/2 [==============================] - 0s 997us/step - loss: 1.5581
# Epoch 532/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.4145
# Epoch 533/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.5481
# Epoch 534/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5566
# Epoch 535/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4117
# Epoch 536/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.3931
# Epoch 537/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9806
# Epoch 538/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9424
# Epoch 539/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.6109
# Epoch 540/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 3.4335
# Epoch 541/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0131
# Epoch 542/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.6690
# Epoch 543/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.8779
# Epoch 544/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9657
# Epoch 545/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5249
# Epoch 546/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5760
# Epoch 547/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7789
# Epoch 548/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.6859
# Epoch 549/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.6011
# Epoch 550/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.2719
# Epoch 551/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.4537
# Epoch 552/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.1010
# Epoch 553/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7356
# Epoch 554/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1298
# Epoch 555/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.6316
# Epoch 556/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.3762
# Epoch 557/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.8930
# Epoch 558/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.7466
# Epoch 559/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.6367
# Epoch 560/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5082
# Epoch 561/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7102
# Epoch 562/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.4526
# Epoch 563/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.6039
# Epoch 564/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4039
# Epoch 565/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.6060
# Epoch 566/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.6823
# Epoch 567/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.2887
# Epoch 568/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 3.1571
# Epoch 569/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.6685
# Epoch 570/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5531
# Epoch 571/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.3714
# Epoch 572/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4297
# Epoch 573/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.4810
# Epoch 574/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.3865
# Epoch 575/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.6577
# Epoch 576/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.4108
# Epoch 577/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.4692
# Epoch 578/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4860
# Epoch 579/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4556
# Epoch 580/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.6813
# Epoch 581/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4191
# Epoch 582/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.4949
# Epoch 583/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4127
# Epoch 584/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.6335
# Epoch 585/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.6499
# Epoch 586/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8913
# Epoch 587/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3973
# ...
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9490
# Epoch 1809/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9424
# Epoch 1810/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9743
# Epoch 1811/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8980
# Epoch 1812/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8954
# Epoch 1813/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9494
# Epoch 1814/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.8670
# Epoch 1815/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0711
# Epoch 1816/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8195
# Epoch 1817/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.2665
# Epoch 1818/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9689
# Epoch 1819/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9819
# Epoch 1820/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0999
# Epoch 1821/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9103
# Epoch 1822/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.3296
# Epoch 1823/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8808
# Epoch 1824/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8933
# Epoch 1825/2000
# 2/2 [==============================] - 0s 998us/step - loss: 0.9986
# Epoch 1826/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8978
# Epoch 1827/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9246
# Epoch 1828/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8437
# Epoch 1829/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9056
# Epoch 1830/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0244
# Epoch 1831/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8904
# Epoch 1832/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8894
# Epoch 1833/2000
# 2/2 [==============================] - 0s 997us/step - loss: 0.8571
# Epoch 1834/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8718
# Epoch 1835/2000
# 2/2 [==============================] - 0s 998us/step - loss: 0.8783
# Epoch 1836/2000
# 2/2 [==============================] - 0s 999us/step - loss: 0.8475
# Epoch 1837/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9799
# Epoch 1838/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8639
# Epoch 1839/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8671
# Epoch 1840/2000
# 2/2 [==============================] - 0s 999us/step - loss: 0.7948
# Epoch 1841/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.3857
# Epoch 1842/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.1324
# Epoch 1843/2000
# 2/2 [==============================] - 0s 998us/step - loss: 0.8951
# Epoch 1844/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.7933
# Epoch 1845/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9875
# Epoch 1846/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.8524
# Epoch 1847/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.9138
# Epoch 1848/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8933
# Epoch 1849/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.1087
# Epoch 1850/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.9357
# Epoch 1851/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9183
# Epoch 1852/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.8516
# Epoch 1853/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9627
# Epoch 1854/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9808
# Epoch 1855/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0003
# Epoch 1856/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9343
# Epoch 1857/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8241
# Epoch 1858/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.3387
# Epoch 1859/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8691
# Epoch 1860/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.6977
# Epoch 1861/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9814
# Epoch 1862/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.7715
# Epoch 1863/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.4632
# Epoch 1864/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2799
# Epoch 1865/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8994
# Epoch 1866/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.0117
# Epoch 1867/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.1372
# Epoch 1868/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.1080
# Epoch 1869/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0767
# Epoch 1870/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9772
# Epoch 1871/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.8848
# Epoch 1872/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0912
# Epoch 1873/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0623
# Epoch 1874/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.1511
# Epoch 1875/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9444
# Epoch 1876/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1351
# Epoch 1877/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.8716
# Epoch 1878/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.9962
# Epoch 1879/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8090
# Epoch 1880/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.4373
# Epoch 1881/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.8355
# Epoch 1882/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.9082
# Epoch 1883/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.1971
# Epoch 1884/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.1977
# Epoch 1885/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.0170
# Epoch 1886/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.2680
# Epoch 1887/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.3737
# Epoch 1888/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.9060
# Epoch 1889/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2686
# Epoch 1890/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.6488
# Epoch 1891/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.1229
# Epoch 1892/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.7652
# Epoch 1893/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9595
# Epoch 1894/2000
# 2/2 [==============================] - 0s 999us/step - loss: 0.8910
# Epoch 1895/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.8858
# Epoch 1896/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0362
# Epoch 1897/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8176
# Epoch 1898/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8591
# Epoch 1899/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1998
# Epoch 1900/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4679
# Epoch 1901/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.2878
# Epoch 1902/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.7002
# Epoch 1903/2000
# 2/2 [==============================] - 0s 999us/step - loss: 0.9037
# Epoch 1904/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.3306
# Epoch 1905/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2490
# Epoch 1906/2000
# 2/2 [==============================] - 0s 998us/step - loss: 2.5964
# Epoch 1907/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.3257
# Epoch 1908/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 2.2786
# Epoch 1909/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.3094
# Epoch 1910/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.3127
# Epoch 1911/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.4678
# Epoch 1912/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.0136
# Epoch 1913/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.2736
# Epoch 1914/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9159
# Epoch 1915/2000
# 2/2 [==============================] - 0s 999us/step - loss: 0.8602
# Epoch 1916/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.9925
# Epoch 1917/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8130
# Epoch 1918/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.2164
# Epoch 1919/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0924
# Epoch 1920/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.0004
# Epoch 1921/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 2.0731
# Epoch 1922/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9622
# Epoch 1923/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0633
# Epoch 1924/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1152
# Epoch 1925/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8460
# Epoch 1926/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.1598
# Epoch 1927/2000
# 2/2 [==============================] - 0s 999us/step - loss: 0.9123
# Epoch 1928/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9874
# Epoch 1929/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3207
# Epoch 1930/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.9505
# Epoch 1931/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.9098
# Epoch 1932/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.8976
# Epoch 1933/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9120
# Epoch 1934/2000
# 2/2 [==============================] - 0s 999us/step - loss: 0.8789
# Epoch 1935/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0805
# Epoch 1936/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.0417
# Epoch 1937/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0242
# Epoch 1938/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9441
# Epoch 1939/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.5208
# Epoch 1940/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0901
# Epoch 1941/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7705
# Epoch 1942/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.2007
# Epoch 1943/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.7987
# Epoch 1944/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.4026
# Epoch 1945/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.7817
# Epoch 1946/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.3350
# Epoch 1947/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.7294
# Epoch 1948/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.2177
# Epoch 1949/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5490
# Epoch 1950/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.9435
# Epoch 1951/2000
# 2/2 [==============================] - 0s 999us/step - loss: 0.9317
# Epoch 1952/2000
# 2/2 [==============================] - 0s 998us/step - loss: 0.8074
# Epoch 1953/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8172
# Epoch 1954/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9131
# Epoch 1955/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9494
# Epoch 1956/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0533
# Epoch 1957/2000
# 2/2 [==============================] - 0s 998us/step - loss: 1.0012
# Epoch 1958/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1866
# Epoch 1959/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8882
# Epoch 1960/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8606
# Epoch 1961/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.9699
# Epoch 1962/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8499
# Epoch 1963/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0440
# Epoch 1964/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8951
# Epoch 1965/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0347
# Epoch 1966/2000
# 2/2 [==============================] - 0s 997us/step - loss: 0.9866
# Epoch 1967/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 0.9784
# Epoch 1968/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8950
# Epoch 1969/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9233
# Epoch 1970/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.3612
# Epoch 1971/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.7515
# Epoch 1972/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.3694
# Epoch 1973/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9973
# Epoch 1974/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2314
# Epoch 1975/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9987
# Epoch 1976/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.3254
# Epoch 1977/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.8917
# Epoch 1978/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0450
# Epoch 1979/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8348
# Epoch 1980/2000
# 2/2 [==============================] - 0s 999us/step - loss: 0.9902
# Epoch 1981/2000
# 2/2 [==============================] - 0s 985us/step - loss: 0.8281
# Epoch 1982/2000
# 2/2 [==============================] - 0s 999us/step - loss: 0.7827
# Epoch 1983/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.0805
# Epoch 1984/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 0.7827
# Epoch 1985/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7331
# Epoch 1986/2000
# 2/2 [==============================] - 0s 999us/step - loss: 0.8795
# Epoch 1987/2000
# 2/2 [==============================] - 0s 1000us/step - loss: 1.2881
# Epoch 1988/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9062
# Epoch 1989/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.6208
# Epoch 1990/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1893
# Epoch 1991/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.2948
# Epoch 1992/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7010
# Epoch 1993/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.8236
# Epoch 1994/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.7136
# Epoch 1995/2000
# 2/2 [==============================] - 0s 999us/step - loss: 1.7745
# Epoch 1996/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2223
# Epoch 1997/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0442
# Epoch 1998/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5154
# Epoch 1999/2000
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0826
# Epoch 2000/2000
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0070

# %%
x_fit = np.linspace(0, 50)
y_fit = modell1.predict(x_fit)

plt.plot(x,y)
plt.plot(x_fit, y_fit)

# %% [markdown]
# #### c) og d)

# %%
# Løsning uten funksjon
derivert = []
for i in range(1,len(volum)):
    der = (pH[i]-pH[i-1])/(volum[i] - volum[i-1])
    derivert.append(der)

# Løsning med funksjon
def numder(x,y):
    derivert = []
    for i in range(len(y)-1):
        der = (y[i+1]-y[i])/(x[i+1]-x[i])
        derivert.append(der)
    return derivert

def finnmaks(liste):
    maks = liste[0]
    for i in range(len(liste)):
        if liste[i] > maks:
            maks = liste[i]
            indeks = i
    return maks,indeks

derivert = numder(xny,y)
maksimum,indeks = finnmaks(derivert) # Finner indeksen til maksderivert i lista
ekv_volum = xny[indeks] 
pH_ekvivalens = y[indeks]

print(f"Ekvivalenspunktet ble nådd ved tilsats av {ekv_volum:.2f} mL 0.10 M NaOH. Da var pH-en {pH_ekvivalens:.2f}")
# Out:
# Ekvivalenspunktet ble nådd ved tilsats av 33.52 mL 0.10 M NaOH. Da var pH-en 8.76

# %% [markdown]
# Den deriverte forteller oss om endringen i pH-en ved hvert minste tilsatte volum NaOH. Der endringen er størst, er den deriverte størst. Dette er ved ekvivalenspunktet, og vi kan derfor finne dette ved å finne maksverdien til den deriverte av pH-en.

# %% [markdown]
# ### 8.2
# #### a)

# %%
import numpy as np

Ka = 1.50E-4
Kw = 1E-14
Kb = Kw/Ka
c_NaOH = 0.500  # mol/L
V_NaOH = ekv_volum*1E-3 # L
n_NaOH = c_NaOH*V_NaOH  # mol
V_glykolsyre = 0.0100   # L
n_glykolsyre = n_NaOH   # mol
c_glykolsyre = n_glykolsyre/V_glykolsyre # mol/L

print(f'Konsentrasjonen av glykolsyre er: {c_glykolsyre:.4f}, mol/L')

# Utregna pH-verdi ved ekvivalenspunktet

V_total = (V_NaOH + V_glykolsyre)
c_glykolsyre_ekv = n_glykolsyre/V_total
c_OH = np.sqrt(Kb*c_glykolsyre_ekv)
pOH = -np.log10(c_OH)
pH = 14-pOH
print(f'pH ved ekvivalenspunktet er: {pH:.2f}')
# Out:
# Konsentrasjonen av glykolsyre er: 1.6761, mol/L
# pH ved ekvivalenspunktet er: 8.70

# %%
ca=c_glykolsyre
Va=V_glykolsyre
cb=c_NaOH
Vb=V_NaOH
Vt=Va+Vb

def T(H):
    return Vt*(H+Ka)*H**2+cb*Vb*(H+Ka)*H-Kw*Vt*(H+Ka)-ca*Va*Ka*H

H1=np.linspace(-1,1,1001)
H2=np.linspace(-1e-8,1e-8,1001)

plt.plot(H1,T(H1))
plt.grid()
plt.show()

plt.plot(H2,T(H2))
plt.grid()
plt.show()

# %% [markdown]
# Vi ser at vi har å gjøre med en tredjegradsfunksjon med tre nullpunkter. Funksjonen er nokså flat rundt nullpunktene. Siden konsentrasjon ikke kan være negativ, ønsker vi nullpunktet der konsentrasjonen er positiv. Når vi zoomer kraftig inn, kan vi se at nullpunktet ligger rundt $0.25\cdot 10^{-8}$. Vi velger derfor dette som startgjett. Toleransen må være svært liten siden vi har med svært små tall å gjøre.

# %% [markdown]
# #### Newtons metode
# Newtons metode er en metode for å finne nullpunkter og løse likninger. Den tilnærmer nullpunktet til en funksjon ved nullpuktet $x_1$ til tangenten i et punkt på funksjonen, $f(x_0)$. Deretter benyttes lager vi en ny tangent ut fra dette punktet, $f(x_1)$ for å på ny tilnærme nullpunktet til funksjonen med nullpunktet til den nye tangenten, $x_2$. Dette er altså en iterativ algoritme:
#
# $$x_{n+1} = x_n - \frac{f(x_n)}{f'(x_n)}$$

# %%
# Den analytisk deriverte av funksjonen
def Tder(H):
    return Vt*3*H**2+Vt*Ka*2*H+cb*Vb*(2*H+Ka)-Kw*Vt-ca*Va*Ka

def newtons_metode(f,fder,x,tol=1E-12,maksiter=100):
    """
    Newtons metode for å finne nullpunkter.
    f: funksjonen som vi skal finne nullpunktene til
    fder: den analytisk deriverte av funksjonen
    x: startgjett
    tol: toleranse for feil
    maksiter: maks antall tillatte iterasjoner
    """
    i = 0
    while abs(f(x)/fder(x)) > tol and i < maksiter:
        x = x - f(x)/fder(x)
        i += 1
    return x, i

H3O,i = newtons_metode(T,Tder,0.25E-8)
print(f'Konsentrasjonen av oksoniumioner ved ekvivalenspunktet er tilnærmet {H3O} etter {i} iterasjoner.')
# Out:
# Konsentrasjonen av oksoniumioner ved ekvivalenspunktet er tilnærmet 1.9739420600571412e-09 etter 2 iterasjoner.

# %%
pH = -np.log10(H3O)
print(f'pH-en ved ekvivalenspunktet er: {pH:.2f}')
# Out:
# pH-en ved ekvivalenspunktet er: 8.70

# %% [markdown]
# Vi ser at pH-en er lik den analytisk utregnede verdien. Det betyr at metoden i dette tilfellet fungerer veldig bra. Avviket fra pH-en vi fikk ved derivasjon av datasettet er heller ikke stort.
